# %%
import numpy as np

# %% [markdown]
# ## t-Test

# %%
import scipy.stats as stats
import math
import matplotlib.pyplot as plt

# %%
school_ages=stats.poisson.rvs(loc=18,mu=35,size=1500)
class_ages=stats.poisson.rvs(loc=18,mu=100,size=60)

import seaborn as sns
sns.distplot(school_ages, bins=40)

# %%
school_ages.mean()
# Out:
# 52.812

# %%
class_ages.mean()
# Out:
# 51.333333333333336
