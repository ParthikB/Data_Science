# %%
import pandas as pd
import seaborn as sns

# %%
dataset = pd.read_csv('./database/Iris.csv')

dataset.drop(columns=['Id'], inplace=True)

dataset.head()
# Out:
#    SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0            5.1           3.5            1.4           0.2  Iris-setosa
# 1            4.9           3.0            1.4           0.2  Iris-setosa
# 2            4.7           3.2            1.3           0.2  Iris-setosa
# 3            4.6           3.1            1.5           0.2  Iris-setosa
# 4            5.0           3.6            1.4           0.2  Iris-setosa

# %% [markdown]
# # Univariate Analysis

# %%
FEATURES = [f for f in dataset.columns if f != 'Species']

plt.figure(figsize=(20, 10))
for idx, f in enumerate(FEATURES): 
    plt.subplot(2, 2, idx+1)
    sns.scatterplot(x=dataset[f], y=np.zeros_like(dataset[f]), data=dataset, hue='Species')

# %% [markdown]
# Here, we can see that:
# * PetalLengthCm and PetalWidthCm directly differentiate between the Species with minimal overlapping.
# * SepalLengthCm and SepalWidthCm also are directly differentiating but we can see some overlapping of species there.

# %% [markdown]
# # Bivariate Analysis

# %%
sns.scatterplot(x='PetalLengthCm', y='SepalLengthCm', data=dataset, hue='Species')

# %% [markdown]
# # Multivariate Analysis

# %%
sns.pairplot(dataset, hue='Species', size=3)
